# %% [markdown]
# # Model evaluation by ecotype
# Evaluate the evaporative stress index parameterization at different IGBP ecotypes using FLUXNET 2015 data. β values are calculated for each ecotype, and data is grouped by ecotype depending on the success of the parameterization in describing the Priestly Taylor evaporative stress index. <br><br>This notebook uses functions defined in the utils notebook, and are not explicity described here.
#
# **Input:**
#  - FLUXNET 2015 monthly csv from data_wrangling.ipynb<br>
#
# **Output:**
#  - Figures

# %% [markdown]
# # Import notebook dependencies

# %%
"""FLUXNET_ecotype_analysis.ipynb 

Notebook for computing beta and ESI for FLUXNET 2015 dataset 

Author: Nicole Keeney 
Date Created: Dec 2020
Modification History: 
    - computing Beta by site, cleaning notebook, changed utils.ipynb to a python module (May 2021)

"""

import pandas as pd 
import numpy as np 
import os
from scipy import optimize
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score 
from sklearn.metrics import mean_squared_error
import seaborn as sns

#import functions from other notebooks
import utils as utils

#increase resolution of plots in jupyter notebook
# %config InlineBackend.figure_format = 'retina'
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 75

# %% [markdown]
# # Load data file from repository

# %%
pathname = 'data/FLUXNET2015_monthly.csv'
fluxMonthly = pd.read_csv(pathname)
display(fluxMonthly[:5])
# Out:
#          DATE FLUXNET-ID IGBP  LE (W/m^2)  VPD (kPa)  TA (deg C)  \
# 0  2011-01-01     US-CRT  CRO    5.317504   0.101241   -5.489418
# 1  2011-02-01     US-CRT  CRO   11.828405   0.145528   -2.971717
# 2  2011-03-01     US-CRT  CRO   34.717653   0.197390    2.153819
# 3  2011-04-01     US-CRT  CRO   45.258565   0.307019    7.368077
# 4  2011-05-01     US-CRT  CRO   82.249253   0.444950   15.870246
#
#    NETRAD (W/m^2)  G (W/m^2)    PA (kPa)        RH  Std Dev RH
# 0        9.618696  -4.961629   99.831905  0.757487    0.102424
# 1       20.088240  -0.771094   99.859839  0.737630    0.134346
# 2       92.061066  11.126964  100.084974  0.747895    0.144803
# 3       96.613316  11.045620   99.294018  0.737826    0.150827
# 4      143.585133  13.552872   99.448677  0.794998    0.157474

# %% [markdown]
# # Compute β by site

# %%
site_names = fluxMonthly["FLUXNET-ID"].unique() # Get unique site names in FLUXNET database 

#empty list for storing beta values
betas = []
for site in site_names: 
    
    # Get all data for that one site, stored as a dataframe
    fluxSite = fluxMonthly.loc[fluxMonthly["FLUXNET-ID"] == site].reset_index(drop = True) 
    
    # Compute ESI from Priestly Taylor equation
    fluxSite = utils.addESI_PT(fluxSite, upperLimit = 1)
    
    # Compute Beta
    betaSite = utils.minimize_b(x = fluxSite['RH'].values, 
                               y = fluxSite['ESI PT (W/m^2)'].values, 
                               VPD = fluxSite['VPD (kPa)'].values)
    betas.append(betaSite)

# %% [markdown]
# ## Drop values of β > some upper bound (I chose 10)
# I feel like beta values > 10 are just bad values. You could easily change this though.

# %%
upper_bound = 10
beta_by_site_df = pd.DataFrame({"Site Name": site_names, "Beta": betas})
beta_by_site_df = beta_by_site_df.where(beta_by_site_df["Beta"] <= upper_bound, np.nan).dropna()
display(beta_by_site_df)
# Out:
#     Site Name  Beta
# 0      US-CRT  1.78
# 1      IT-Tor  2.26
# 2      US-Wi6  8.44
# 5      AU-Wac  0.54
# 6      CN-Du3  2.76
# ..        ...   ...
# 141    US-Me5  4.78
# 142    FI-Jok  7.07
# 143    ES-Amo  3.84
# 144    IT-Cpz  5.09
# 145    US-Wi3  2.94
#
# [134 rows x 2 columns]

# %% [markdown]
# ## Make histogram!
# To change the bins, change the variable "upper bound" in the code box above, or change the variable "bins" in the code box below

# %%
bins = np.arange(0, upper_bound + 1, 1) # Set bins
beta_by_site_df.hist(figsize = (10,6), bins = bins) # Create histogram
plt.title("Beta by Site, n = " + str(len(beta_by_site_df)))
plt.xlabel("Beta")
plt.ylabel("Num values")
plt.show() # Show plot

# %% [markdown]
# # Calculate β for each ecotype

# %% [markdown]
# ## Create a table of IGBP ecotypes and descriptions

# %%
igbp_code = ['ALL','CRO','CSH','DBF','EBF','ENF','GRA','MF','OSH','SAV','WET','WSA']
igbp_description = ['All Ecotypes','Croplands','Closed Shrublands','Deciduous Broadleaf Forests',
                    'Evergreen Broadleaf Forests','Evergreen Needleleaf Forests','Grasslands',
                    'Mixed Forests','Open Shrublands','Savannas','Permanent Wetlands',
                    'Woody Savannas']
dfECO = pd.DataFrame({'IGBP' : igbp_code,'Description': igbp_description})

# %% [markdown]
# ## Compute β

# %%
#empty list for storing beta values
ecoList, betas, numValues = [],[],[]
for ecotype in dfECO['IGBP'].values:
    #restrict dataframe by ecotype
    if ecotype == 'ALL': 
        fluxEco = fluxMonthly.copy()
    else:
        fluxEco = fluxMonthly.loc[fluxMonthly['IGBP'] == ecotype].reset_index(drop = True)
    
    #compute ESI from Priestly Taylor equation
    fluxEco = utils.addESI_PT(fluxEco, upperLimit = 1)
    
    #compute Beta
    betaEco = utils.minimize_b(x = fluxEco['RH'].values, y = fluxEco['ESI PT (W/m^2)'].values, VPD = fluxEco['VPD (kPa)'].values)
    
    #add ESI parameterization from Beta calculation as column to the table 
    ESI_B = [utils.f_RH(RH = fluxEco['RH'].values[i], VPD = fluxEco['VPD (kPa)'].values[i], B = betaEco) for i in range(len(fluxEco))]
    fluxEco.insert(loc = 4, column = 'model ESI (W/m^2)', value = ESI_B)
    
    #append values to list
    ecoList.append(fluxEco)
    betas.append(betaEco)
    numValues.append(len(fluxEco))

# %% [markdown]
# ## Add data to table
# Add β values and total data points used in calculation as columns to table.

# %%
dfECO['β value'] = betas
dfECO['Num values used in β calculation'] = numValues
display(dfECO)
# Out:
#    IGBP                   Description  β value  \
# 0   ALL                  All Ecotypes     2.33
# 1   CRO                     Croplands     1.71
# 2   CSH             Closed Shrublands     4.97
# 3   DBF   Deciduous Broadleaf Forests     3.67
# 4   EBF   Evergreen Broadleaf Forests     2.32
# 5   ENF  Evergreen Needleleaf Forests     3.11
# 6   GRA                    Grasslands     1.29
# 7    MF                 Mixed Forests     4.80
# 8   OSH               Open Shrublands     2.74
# 9   SAV                      Savannas     0.78
# 10  WET            Permanent Wetlands     4.80
# 11  WSA                Woody Savannas     1.05
#
#     Num values used in β calculation
# 0                               7477
# 1                                560
# 2                                109
# 3                                863
# 4                                392
# 5                               2194
# 6                               1323
# 7                                593
# 8                                322
# 9                                329
# 10                               332
# 11                               452

# %% [markdown]
# # Generate plots by ecotype, and calculate SSR
# SSR = sum of square residuals, a way to evaluate fit of model

# %%
SSRList, RMSEList = [],[]
for i in range(len(ecoList)): 
    df = ecoList[i]
    
    #calculate residuals 
    residuals = np.array([df['model ESI (W/m^2)'][i]-df['ESI PT (W/m^2)'][i] for i in range(len(df['ESI PT (W/m^2)']))])
    SSR = round(np.mean(np.abs(residuals**2)),3)
    SSRList.append(SSR)
    RMSE = np.sqrt(mean_squared_error(df['ESI PT (W/m^2)'],df['model ESI (W/m^2)']))
    RMSEList.append(RMSE)

    #plot
    utils.plotESI(RH = df['RH'].values, ESI_PT = df['ESI PT (W/m^2)'].values, ESI_B = df['model ESI (W/m^2)'].values, Beta = dfECO['β value'].values[i], title = dfECO['Description'].values[i] + ' (n = ' + str(dfECO['Num values used in β calculation'].values[i]) + ')', 
                  markersize = 5, figPath = 'figs/FLUXNET_analysis/ecotype/' + dfECO['IGBP'].values[i] + '.png')

#add SSR as column to table 
dfECO['SSR'] = SSRList
dfECO['RMSE'] = RMSEList

# %% [markdown]
# # Solve for β for best fit ecotypes
# Here we solve for β for all ecotypes that have SSR < 0.075

# %% [markdown]
# ## Sort table by smallest sum of square residuals
# The residual in this case represents model ESI - Priestley Taylor ESI (not a regression line)

# %%
dfECO = dfECO.sort_values(by = 'RMSE', ascending = True)
display(dfECO)
# Out:
#    IGBP                   Description  β value  \
# 11  WSA                Woody Savannas     1.05
# 2   CSH             Closed Shrublands     4.97
# 9   SAV                      Savannas     0.78
# 8   OSH               Open Shrublands     2.74
# 6   GRA                    Grasslands     1.29
# 4   EBF   Evergreen Broadleaf Forests     2.32
# 1   CRO                     Croplands     1.71
# 5   ENF  Evergreen Needleleaf Forests     3.11
# 0   ALL                  All Ecotypes     2.33
# 7    MF                 Mixed Forests     4.80
# 3   DBF   Deciduous Broadleaf Forests     3.67
# 10  WET            Permanent Wetlands     4.80
#
#     Num values used in β calculation    SSR      RMSE
# 11                               452  0.035  0.187027
# 2                                109  0.047  0.216417
# 9                                329  0.049  0.222128
# 8                                322  0.053  0.231078
# 6                               1323  0.060  0.245868
# 4                                392  0.075  0.273400
# 1                                560  0.088  0.295992
# 5                               2194  0.090  0.299621
# 0                               7477  0.102  0.318755
# 7                                593  0.122  0.349158
# 3                                863  0.149  0.386205
# 10                               332  0.199  0.446557

# %%
#compile best fit ecotypes into a single dataframe
ecoListBestFit = []

for ecotype in ['WSA', 'SAV', 'GRA']:
    fluxEco = fluxMonthly.loc[fluxMonthly['IGBP'] == ecotype].reset_index(drop = True)
    if len(fluxEco) >=12 : 
        ecoListBestFit.append(fluxEco)
    
df = pd.concat(ecoListBestFit).reset_index()

#compute ESI from Priestly Taylor equation
df = utils.addESI_PT(df)
    
#compute Beta
betaEco = utils.minimize_b(x = df['RH'].values, y = df['ESI PT (W/m^2)'].values, VPD = df['VPD (kPa)'].values)
print('β best fit = ' + str(1/betaEco))    
    
#add ESI parameterization from Beta calculation as column to the table 
ESI_B = [utils.f_RH(RH = df['RH'].values[i], VPD = df['VPD (kPa)'].values[i], B = betaEco) for i in range(len(df))]
df.insert(loc = 4, column = 'model ESI (W/m^2)', value = ESI_B)

#calculate residuals 
residuals = np.array([df['ESI PT (W/m^2)'][i]-df['model ESI (W/m^2)'][i] for i in range(len(df['ESI PT (W/m^2)']))])
SSR = round(np.mean(np.abs(residuals**2)),3)
print('SSR = ' + str(SSR))

#rmse
rms = mean_squared_error(df['ESI PT (W/m^2)'].values, df['model ESI (W/m^2)'].values, squared=False)
print(rms*100)

#plot
utils.plotESI(RH = df['RH'].values, ESI_PT = df['ESI PT (W/m^2)'].values, ESI_B = df['model ESI (W/m^2)'].values, Beta = betaEco, 
              title = "Savannas, Woody Savannas, and Grasslands (n = 827)", markersize = 3, figPath = 'figs/FLUXNET_analysis/model_vs_tower.png') 

#plot residuals
utils.plotResiduals(RH = df['RH'].values, residuals = residuals, title = "Savannas, Woody Savannas, and Grasslands", figPath = 'figs/FLUXNET_analysis/residuals.png')
# Out:
# β best fit = 0.9090909090909091
# SSR = 0.055
# 23.43264571088339

# %%
#initialize figure and axes
fig = plt.figure(figsize = (6,4))
ax = plt.axes([0,0,1,1])
gridlines = plt.grid(b = True, linestyle = '--', alpha = 0.4) #add gridlines 

#generate plot
ax = sns.regplot(x=df['ESI PT (W/m^2)'], y=df['model ESI (W/m^2)'], color = 'darkblue', ci=None, truncate=False, label = 'ESI')

#compute r^2 
r_squared = round(r2_score(df['ESI PT (W/m^2)'], df['model ESI (W/m^2)']),2)
ax.text(x = 0.05, y = 0.95, s = 'r^2 = ' + str(r_squared), horizontalalignment = 'left', verticalalignment = 'top', fontsize = 13, transform = ax.transAxes, bbox = {'facecolor':'whitesmoke', 'edgecolor':'grey'})

#make plot pretty 
plt.xlabel('ESI tower data')
plt.ylabel('f(RH) = RH^(VPD*β)')

#save and display figure
plt.savefig('figs/FLUXNET_analysis/regression_analysis.png', bbox_inches='tight', dpi = 250)
plt.show()

# %% [markdown]
# # Generate histogram of betas for each site used in final analysis

# %%
site_names = fluxEco["FLUXNET-ID"].unique() # Get unique site names in FLUXNET database 

#empty list for storing beta values
betas = []
for site in site_names: 
    
    # Get all data for that one site, stored as a dataframe
    fluxSite = fluxEco.loc[fluxEco["FLUXNET-ID"] == site].reset_index(drop = True) 
    
    # Compute ESI from Priestly Taylor equation
    fluxSite = utils.addESI_PT(fluxSite, upperLimit = 1)
    
    # Compute Beta
    betaSite = utils.minimize_b(x = fluxSite['RH'].values, 
                               y = fluxSite['ESI PT (W/m^2)'].values, 
                               VPD = fluxSite['VPD (kPa)'].values)
    betas.append(betaSite)
    
beta_by_site_df = pd.DataFrame({"Site Name": site_names, "Beta": betas})

# %%
ax = beta_by_site_df.plot(figsize = (13,5), xticks = beta_by_site_df.index, rot = 70, marker = 'o', grid = True)
ax.set_xticklabels(beta_by_site_df["Site Name"])
plt.ylabel("Beta")
plt.xlabel("Site name")
plt.title("Beta for each site used in final analysis")
plt.show()

# %% [markdown]
# I want to drop those two large values in the middle for those two sites! It makes the histogram look better. You can keep them, if you want (just delete the below code chunk)

# %%
# Drop values > upper bound
upper_bound = 5
orig_len = len(beta_by_site_df)
beta_by_site_df = beta_by_site_df.where(beta_by_site_df["Beta"] <= upper_bound, np.nan).dropna()
len_after_dropping = len(beta_by_site_df)
print("With a maximum beta limit of " + str(upper_bound) + ", " + str(orig_len - len_after_dropping) + " sites were dropped")
# Out:
# With a maximum beta limit of 5, 2 sites were dropped

# %%
# Make histogram
beta_by_site_df.hist(figsize = (10,6), bins = 10) # Create histogram
plt.title("Beta by Site, n = " + str(len(beta_by_site_df)))
plt.xlabel("Beta")
plt.ylabel("Num values")
plt.show() # Show plot
